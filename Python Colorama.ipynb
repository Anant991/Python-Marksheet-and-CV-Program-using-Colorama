# %%
from colorama import *

# %%
print("\t\t\t\t"+Fore.RED+Back.CYAN+Style.BRIGHT+"MARIANA ANDERSON\n"+Style.RESET_ALL+"\t\t\t\t"+Fore.RED+Back.CYAN+Style.BRIGHT+"Marketing Manager\n"+Style.RESET_ALL+"\t\t\t\t"+Fore.RED+Back.CYAN+Style.BRIGHT+"Phone NO.8578434598\n\n\n"+Style.RESET_ALL)
print(Fore.BLACK+Back.LIGHTMAGENTA_EX+Style.BRIGHT+"OBJECTIVE\n"+Style.RESET_ALL+Fore.GREEN+"Store Manager equipped with entensive experience in automobile sales management.\nEmployee excellent leadership skills and multi tasking strengths.Demonstrated\nability to imoprove store operations,increse top line sales and reduce costs.\n\n")
print(Fore.BLACK+Back.LIGHTMAGENTA_EX+Style.BRIGHT+"CONTACT ME"+Style.RESET_ALL+"\t\t\t\t"+Fore.BLACK+Back.LIGHTMAGENTA_EX+Style.BRIGHT+"WORK EXPERIENCE\n"+Style.RESET_ALL)
print(Fore.GREEN+"123 Anywhere, New Delhi                 Luxury Car Center,New Delhi")
print(Fore.GREEN+"hello@reallygmail.com                   Store Manager")
print(Fore.GREEN+"Phone No.8578434598                     Motivate and coach employee to meet service, sales and repair goals\n\t\t\t\t\tCreate and modify employee schedule with service levels in mind\n\t\t\t\t\tRecruit and hire top mechanics, services advisors and sales peoples\n\n")
print(Fore.BLACK+Back.LIGHTMAGENTA_EX+Style.BRIGHT+"EDUCATION"+Style.RESET_ALL+"\t\t\t\t"+Fore.BLACK+Back.LIGHTMAGENTA_EX+Style.BRIGHT+"SKILLS\n"+Style.RESET_ALL)
print(Fore.GREEN+"XYZ XYX University                      Skill No 1")
print(Fore.GREEN+"2006-2008                               Skill No 2")
print(Fore.GREEN+"                                        Skill No 3")
print(Fore.GREEN+"ABC ABZ School                          Skill No 4")
print(Fore.GREEN+"2008-2010                               Skill No 5\n\n")
print(Fore.BLACK+Back.LIGHTMAGENTA_EX+Style.BRIGHT+"HIGHLIGHTS"+Style.RESET_ALL+"\t\t\t\t"+Fore.BLACK+Back.LIGHTMAGENTA_EX+Style.BRIGHT+"HOBBIES\n"+Style.RESET_ALL)
print(Fore.GREEN+"Result Oriented                         Playing Chess")
print(Fore.GREEN+"Revenue generation                      Travelling")
print(Fore.GREEN+"Business Development                    Listening Music")
print(Fore.GREEN+"Resistance to stress                    Computer games")
print(Fore.GREEN+"Good Manners\nAbility to motivate staff\nEffective Marketing\n\n")
print(Fore.BLACK+Back.LIGHTMAGENTA_EX+Style.BRIGHT+"REFERENCES\n"+Style.RESET_ALL+Fore.GREEN+"Name Surname\nJob Position\nPhone No.:9557597394\nEmail:helloreally@gmail.com")
# Out:
# 				MARIANA ANDERSON
# 				Marketing Manager
# 				Phone NO.8578434598
#
#
#
# OBJECTIVE
# Store Manager equipped with entensive experience in automobile sales management.
# Employee excellent leadership skills and multi tasking strengths.Demonstrated
# ability to imoprove store operations,increse top line sales and reduce costs.
#
#
# CONTACT ME				WORK EXPERIENCE
#
# 123 Anywhere, New Delhi                 Luxury Car Center,New Delhi
# hello@reallygmail.com                   Store Manager
# Phone No.8578434598                     Motivate and coach employee to meet service, sales and repair goals
# 					Create and modify employee schedule with service levels in mind
# 					Recruit and hire top mechanics, services advisors and sales peoples
#
#
# EDUCATION				SKILLS
#
# XYZ XYX University                      Skill No 1
# 2006-2008                               Skill No 2
#                                         Skill No 3
# ABC ABZ School                          Skill No 4
# ...

# %%
roll_no=int(input("Enter Roll Number:"))
name=input("Enter Student Name:")
gender=input("Enter Student Gender:")
standard=int(input("Enter Student Class:"))
english=int(input("Enter English marks:"))
physics=int(input("Enter Physics marks:"))
chemistry=int(input("Enter Chemistry marks:"))
maths=int(input("Enter Maths marks:"))
hindi=int(input("Enter Hindi marks:"))
obtained_total_marks=english+physics+chemistry+maths+hindi
print(obtained_total_marks)
percentage=obtained_total_marks/500*100
print(percentage)
print("\n\n"+Fore.RED+Back.CYAN+Style.BRIGHT+"STUDENT MARKSHGEET\n"+Style.RESET_ALL)
print("Your Roll no is",roll_no)
print("Your Name is",name)
print("Your Gender is",gender)
print("Your Class is",standard)
print("Total Marks:500")
print("Obtained Marks:",obtained_total_marks)
print("Your Percentage is:",percentage)
if percentage>=80:
    print("Grade: A1")
    print("Remarks: Excellent")
elif percentage>=70:
    print("Grade: A")
    print("Remarks: Ver Good")
elif percentage>=60:
    print("Grade: B")
    print("Remarks: Good")
elif percentage>=50:
    print("Grade: C")
    print("Remarks: Fair")
elif percentage>=40:
    print("Grade: D")
    print("Remarks: Poor")
elif percentage>=33:
    print("Grade: E")
    print("Remarks: Very Poor/Need Improvement")
else:
    print("Grade: F\nStudent is Failed in Exam")
    print("Remarks: Fail")
# Out:
# Enter Roll Number:03
# Enter Student Name:Anant Kala
# Enter Student Gender:Male
# Enter Student Class:12
# Enter English marks:78
# Enter Physics marks:87
# Enter Chemistry marks:89
# Enter Maths marks:95
# Enter Hindi marks:92
# 441
# 88.2
#
#
# STUDENT MARKSHGEET
#
# Your Roll no is 3
# Your Name is Anant Kala
# Your Gender is Male
# Your Class is 12
# Total Marks:500
# Obtained Marks: 441
# Your Percentage is: 88.2
# Grade: A1
# Remarks: Excellent

# %%
serial_no=int(input("Enter Serial Number:"))
roll_no=int(input("Enter Roll Number:"))
name=input("Enter Student Name:")
father_name=input("Enter Student Father Name:")
mother_name=input("Enter Student Mother Name:")
DOB=int(input("Enter Student Date of Birth:"))
DOB_words=input("Enter Student Date of Birth in Words:")
standard=int(input("Enter Student Class:"))
school_name=input("Enter Student School Name:")
english=int(input("Enter English marks:"))
physics=int(input("Enter Physics marks:"))
chemistry=int(input("Enter Chemistry marks:"))
maths=int(input("Enter Maths marks:"))
hindi=int(input("Enter Hindi marks:"))
obtained_total_marks=english+physics+chemistry+maths+hindi
print(obtained_total_marks)
percentage=obtained_total_marks/500*100
print(percentage)
print("\n\n"+Fore.RED+Back.CYAN+Style.BRIGHT+"STUDENT MARKSHGEET\n"+Style.RESET_ALL)
print("Student Roll no is:", roll_no)
print("Student Name is:", name)
print("Student Fathers Name is:", father_name)
print("Student Mothers Name is:", mother_name)
print("Student Date of birth is:", DOB)
print("Student Date of birth in Words is:", DOB_words)
print("Student Class is:", standard)
print("Student School Name is:", school_name)
print("Student English Marks:", english)
print("Student Physics Marks:", physics)
print("Student Chemistry Marks:", chemistry)
print("Student Maths Marks:", maths)
print("Student Hindi Marks:", hindi)
print("Total Marks:500")
print("Obtained Marks:", obtained_total_marks)
print("Your Percentage is:", percentage)
if percentage>=80:
    print("Grade: A1")
    print("Status:Passed")
    print("Remarks: Excellent")
elif percentage>=70:
    print("Grade: A")
    print("Status:Passed")
    print("Remarks: Very Good")
elif percentage>=60:
    print("Grade: B")
    print("Status:Passed")
    print("Remarks: Good")
elif percentage>=50:
    print("Grade: C")
    print("Status:Passed")
    print("Remarks: Fair")
elif percentage>=40:
    print("Grade: D")
    print("Status:Passed")
    print("Remarks: Poor")
elif percentage>=33:
    print("Grade: E")
    print("Status:Passed")
    print("Remarks: Very Poor/Need Improvement")
else:
    print("Grade: F")
    print("Status:Failed")
    print("Remarks: Very Very Poor/Need High Level Improvement")
print("\n\n")
print(Fore.RED+Back.YELLOW+Style.BRIGHT+"Sr. No"+Style.RESET_ALL)
print(serial_no)
print("\t\t\t\t"+Fore.RED+Back.YELLOW+Style.BRIGHT+"BOARD OF SCHOOL EDUCATION UTTRAKHAND"+Style.RESET_ALL)
print("\t\t\t\t"+Fore.RED+Back.YELLOW+Style.BRIGHT+"\tMARKS STATEMENT"+Style.RESET_ALL)
print("\t\t\t\t"+Fore.RED+Back.YELLOW+Style.BRIGHT+"\tHIGH SCHOOL EXAMINATION\n\n"+Style.RESET_ALL)
print(Fore.GREEN+Style.BRIGHT+"STUDENT NAME:",name+Fore.GREEN+Style.BRIGHT+"\t\t\t\t\t\tSTUDENT ROLL NO:",roll_no)
print(Fore.GREEN+Style.BRIGHT+"STUDENT FATHERS NAME:",father_name+Fore.GREEN+Style.BRIGHT+"\t\t\t\t\tSTUDENT MOTHERS NAME:",mother_name)
print(Fore.GREEN+Style.BRIGHT+"STUDENT CLASS:",standard)
print(Fore.GREEN+Style.BRIGHT+"DATE OF BIRTH:",DOB)
print(Fore.GREEN+Style.BRIGHT+"DATE OF BIRTH IN WORDS:",DOB_words)
print(Fore.GREEN+Style.BRIGHT+"SCHOOL NAME:",school_name,"\n\n")
print(Fore.MAGENTA+Style.BRIGHT+"SUB CODE\t\tSUBJECT\t\t\tMAX MARKS\t\tMARKS OBTAINED\t\t")
print(Fore.BLACK+"001\t\t\tHINDI                     100\t\t\t    ",hindi)
print(Fore.BLACK+"028\t\t\tENGLISH                   100\t\t\t    ",english)
print(Fore.BLACK+"031\t\t\tMATHS                     100\t\t\t    ",maths)
print(Fore.BLACK+"034\t\t\tPHYSICS                   100\t\t\t    ",physics)
print(Fore.BLACK+"021\t\t\tCHEMISTRY                 100\t\t\t    ",chemistry,"\n")
print(Fore.BLACK+Style.BRIGHT+"STUDENT GRAND TOTAL/STUDENT TOTAL OBTAINED MARKS:\t\t\t    ",obtained_total_marks,"\n\n")
print(Fore.MAGENTA+Style.BRIGHT+"TOTAL OBTAINED MARKS:",obtained_total_marks)
print(Fore.MAGENTA+Style.BRIGHT+"STUDENT OBTAINED PERCENTAGE:",percentage)
print(Fore.MAGENTA+Style.BRIGHT+"STUDENT OBTAINED GRADE:-")
if percentage>=80:
    print("GRADE: A1")
    print("STATUS:PASSED")
    print("REMARKS: EXCELLENT")
elif percentage>=70:
    print("GRADE A")
    print("STATUS:PASSED")
    print("REMARKS: VERY GOOD")
elif percentage>=60:
    print("GRADE: B")
    print("STATUS:PASSED")
    print("REMARKS: GOOD")
elif percentage>=50:
    print("GRADE: C")
    print("STATUS:PASSED")
    print("REMARKS: FAIR")
elif percentage>=40:
    print("Grade: D")
    print("STATUS:PASSED")
    print("Remarks: Poor")
elif percentage>=33:
    print("GRADE: E")
    print("STATUS:PASSED")
    print("Remarks: VERY POOR/NEED IMPROVEMENT")
else:
    print("GRADE: F")
    print("STATUS:FAILED")
    print("REMARKS: VERY VERY POOR/NEED HIGH LEVEL IMPROVEMENT")
print("\n\n"+Fore.RED+"DATED:-\t\t\t\t\t\tPRINCIPAL SIGNATURE:-")
# Out:
# Enter Serial Number:123456
# Enter Roll Number:160180107003
# Enter Student Name:Anant Kala
# Enter Student Father Name:Arun Kumar Kala
# Enter Student Mother Name:Deepa Kala
# Enter Student Date of Birth:11011999
# Enter Student Date of Birth in Words:Eleven January Nineteen Hundred Ninety Nine
# Enter Student Class:12
# Enter Student School Name:Saraswati Vidya Mandir Pauri Garhwal
# Enter English marks:78
# Enter Physics marks:87
# Enter Chemistry marks:89
# Enter Maths marks:95
# Enter Hindi marks:92
# 441
# 88.2
#
#
# STUDENT MARKSHGEET
#
# Student Roll no is: 160180107003
# Student Name is: Anant Kala
# Student Fathers Name is: Arun Kumar Kala
# Student Mothers Name is: Deepa Kala
# Student Date of birth is: 11011999
# Student Date of birth in Words is: Eleven January Nineteen Hundred Ninety Nine
# Student Class is: 12
# Student School Name is: Saraswati Vidya Mandir Pauri Garhwal
# Student English Marks: 78
# Student Physics Marks: 87
# Student Chemistry Marks: 89
# ...

# %%
serial_no=int(input("Enter Serial Number:"))
roll_no=int(input("Enter Roll Number:"))
name=input("Enter Student Name:")
father_name=input("Enter Student Father Name:")
mother_name=input("Enter Student Mother Name:")
DOB=int(input("Enter Student Date of Birth:"))
DOB_words=input("Enter Student Date of Birth in Words:")
standard=int(input("Enter Student Class:"))
school_name=input("Enter Student School Name:")
english=int(input("Enter English marks:"))
physics=int(input("Enter Physics marks:"))
chemistry=int(input("Enter Chemistry marks:"))
maths=int(input("Enter Maths marks:"))
hindi=int(input("Enter Hindi marks:"))
obtained_total_marks=english+physics+chemistry+maths+hindi
print(obtained_total_marks)
percentage=obtained_total_marks/500*100
print(percentage)
print("\n\n")
print(Fore.RED+Back.YELLOW+Style.BRIGHT+"Sr. No"+Style.RESET_ALL)
print(serial_no)
print("\t\t\t\t"+Fore.RED+Back.YELLOW+Style.BRIGHT+"BOARD OF SCHOOL EDUCATION UTTRAKHAND"+Style.RESET_ALL)
print("\t\t\t\t"+Fore.RED+Back.YELLOW+Style.BRIGHT+"\tMARKS STATEMENT"+Style.RESET_ALL)
print("\t\t\t\t"+Fore.RED+Back.YELLOW+Style.BRIGHT+"\tHIGH SCHOOL EXAMINATION\n\n"+Style.RESET_ALL)
print(Fore.GREEN+Style.BRIGHT+"STUDENT NAME:",name+Fore.GREEN+Style.BRIGHT+"\t\t\t\t\t\tSTUDENT ROLL NO:",roll_no)
print(Fore.GREEN+Style.BRIGHT+"STUDENT FATHERS NAME:",father_name+Fore.GREEN+Style.BRIGHT+"\t\t\t\t\tSTUDENT MOTHERS NAME:",mother_name)
print(Fore.GREEN+Style.BRIGHT+"STUDENT CLASS:",standard)
print(Fore.GREEN+Style.BRIGHT+"DATE OF BIRTH:",DOB)
print(Fore.GREEN+Style.BRIGHT+"DATE OF BIRTH IN WORDS:",DOB_words)
print(Fore.GREEN+Style.BRIGHT+"SCHOOL NAME:",school_name,"\n\n")
print(Fore.MAGENTA+Style.BRIGHT+"SUB CODE\t\tSUBJECT\t\t\tMAX MARKS\t\tMARKS OBTAINED\t\t")
print(Fore.BLACK+"001\t\t\tHINDI                     100\t\t\t    ",hindi)
print(Fore.BLACK+"028\t\t\tENGLISH                   100\t\t\t    ",english)
print(Fore.BLACK+"031\t\t\tMATHS                     100\t\t\t    ",maths)
print(Fore.BLACK+"034\t\t\tPHYSICS                   100\t\t\t    ",physics)
print(Fore.BLACK+"021\t\t\tCHEMISTRY                 100\t\t\t    ",chemistry,"\n")
print(Fore.BLACK+Style.BRIGHT+"STUDENT GRAND TOTAL/STUDENT TOTAL OBTAINED MARKS:\t\t\t   ",obtained_total_marks,"\n\n")
print(Fore.MAGENTA+Style.BRIGHT+"TOTAL OBTAINED MARKS:",obtained_total_marks)
print(Fore.MAGENTA+Style.BRIGHT+"STUDENT OBTAINED PERCENTAGE:",percentage)
print(Fore.MAGENTA+Style.BRIGHT+"STUDENT OBTAINED GRADE:-")
if percentage>=80:
    print("GRADE: A1")
    print("PASSED")
    print("REMARKS: EXCELLENT")
elif percentage>=70:
    print("GRADE A")
    print("PASSED")
    print("REMARKS: VERY GOOD")
elif percentage>=60:
    print("GRADE: B")
    print("PASSED")
    print("REMARKS: GOOD")
elif percentage>=50:
    print("GRADE: C")
    print("PASSED")
    print("REMARKS: FAIR")
elif percentage>=40:
    print("Grade: D")
    print("PASSED")
    print("Remarks: Poor")
elif percentage>=33:
    print("GRADE: E")
    print("PASSED")
    print("Remarks: VERY POOR/NEED IMPROVEMENT")
else:
    print("GRADE: F")
    print("FAILED")
    print("REMARKS: VERY VERY POOR/NEED HIGH LEVEL IMPROVEMENT")
print("\n\n"+Fore.RED+"DATED:-\t\t\t\t\t\tPRINCIPAL SIGNATURE:-")
# Out:
# Enter Serial Number:123456
# Enter Roll Number:160180107003
# Enter Student Name:Anant Kala
# Enter Student Father Name:Arun Kumar Kala
# Enter Student Mother Name:Deepa Kala
# Enter Student Date of Birth:11011999
# Enter Student Date of Birth in Words:Eleven January Nineteen Hundred Ninety Nine
# Enter Student Class:12
# Enter Student School Name:Saraswati Vidya Mandir Pauri Garhwal
# Enter English marks:78
# Enter Physics marks:87
# Enter Chemistry marks:89
# Enter Maths marks:95
# Enter Hindi marks:92
# 441
# 88.2
#
#
#
# Sr. No
# 123456
# 				BOARD OF SCHOOL EDUCATION UTTRAKHAND
# 					MARKS STATEMENT
# 					HIGH SCHOOL EXAMINATION
#
#
# STUDENT NAME: Anant Kala						STUDENT ROLL NO: 160180107003
# STUDENT FATHERS NAME: Arun Kumar Kala					STUDENT MOTHERS NAME: Deepa Kala
# STUDENT CLASS: 12
# DATE OF BIRTH: 11011999
# DATE OF BIRTH IN WORDS: Eleven January Nineteen Hundred Ninety Nine
# SCHOOL NAME: Saraswati Vidya Mandir Pauri Garhwal
#
#
# ...

# %%
serial_no=int(input("Enter Serial Number:"))
roll_no=int(input("Enter Roll Number:"))
name=input("Enter Student Name:")
father_name=input("Enter Student Father Name:")
mother_name=input("Enter Student Mother Name:")
DOB=int(input("Enter Student Date of Birth:"))
DOB_words=input("Enter Student Date of Birth in Words:")
standard=int(input("Enter Student Class:"))
school_name=input("Enter Student School Name:")
school_code=input("Enter Student School Code:")
certificate_sno=input("Enter Student Certificate Number:")
type_exam=input("Enter Student Exam Type:")
english=int(input("Enter English marks:"))
physics=int(input("Enter Physics marks:"))
chemistry=int(input("Enter Chemistry marks:"))
maths=int(input("Enter Maths marks:"))
hindi=int(input("Enter Hindi marks:"))
obtained_total_marks=english+physics+chemistry+maths+hindi
print(obtained_total_marks)
percentage=obtained_total_marks/500*100
print(percentage)
print("\n\n")
print(Fore.RED+Back.YELLOW+Style.BRIGHT+"Sr. No"+Style.RESET_ALL)
print(serial_no)
print("\t\t\t\t"+Fore.RED+Back.YELLOW+Style.BRIGHT+"BOARD OF SCHOOL EDUCATION UTTRAKHAND\n"+Style.RESET_ALL+"\t\t\t\t"+Fore.RED+Back.YELLOW+Style.BRIGHT+"  CERTIFIACTE MARKS STATEMENT\n"+Style.RESET_ALL+"\t\t\t\t"+Fore.RED+Back.YELLOW+Style.BRIGHT+"     INTERMEDIATE EXAMINATION\n\n\n"+Style.RESET_ALL)
print(Fore.GREEN+Style.BRIGHT+"STUDENT NAME:",name,"\n")
print(Fore.GREEN+Style.BRIGHT+"STUDENT ROLL NO:",roll_no,"\n")
print(Fore.GREEN+Style.BRIGHT+"STUDENT FATHERS NAME:",father_name,"\n")
print(Fore.GREEN+Style.BRIGHT+"STUDENT MOTHERS NAME:",mother_name,"\n")
print(Fore.GREEN+Style.BRIGHT+"STUDENT CLASS:",standard,"\n")
print(Fore.GREEN+Style.BRIGHT+"DATE OF BIRTH:",DOB,"\n")
print(Fore.GREEN+Style.BRIGHT+"DATE OF BIRTH IN WORDS:",DOB_words,"\n")
print(Fore.GREEN+Style.BRIGHT+"SCHOOL NAME:",school_name,"\n\n\n")
print(Fore.MAGENTA+Style.BRIGHT+"SUB CODE\t\tSUBJECT\t\t\tMAX MARKS\t\tMARKS OBTAINED\t\t")
print(Fore.BLACK+"001\t\t\tHINDI                     100\t\t\t    ",hindi)
print(Fore.BLACK+"028\t\t\tENGLISH                   100\t\t\t    ",english)
print(Fore.BLACK+"031\t\t\tMATHS                     100\t\t\t    ",maths)
print(Fore.BLACK+"034\t\t\tPHYSICS                   100\t\t\t    ",physics)
print(Fore.BLACK+"021\t\t\tCHEMISTRY                 100\t\t\t    ",chemistry,"\n")
print(Fore.BLACK+Style.BRIGHT+"STUDENT GRAND TOTAL/STUDENT TOTAL OBTAINED MARKS:\t\t\t    ",obtained_total_marks,"\n\n")
print(Fore.MAGENTA+Style.BRIGHT+"TOTAL OBTAINED MARKS:",obtained_total_marks)
print(Fore.MAGENTA+Style.BRIGHT+"STUDENT OBTAINED PERCENTAGE:",percentage)
print(Fore.MAGENTA+Style.BRIGHT+"STUDENT OBTAINED GRADE:-")
if percentage>=80:
    print("GRADE: A1")
    print("PASSED")
    print("REMARKS: EXCELLENT")
elif percentage>=70:
    print("GRADE A")
    print("PASSED")
    print("REMARKS: VERY GOOD")
elif percentage>=60:
    print("GRADE: B")
    print("PASSED")
    print("REMARKS: GOOD")
elif percentage>=50:
    print("GRADE: C")
    print("PASSED")
    print("REMARKS: FAIR")
elif percentage>=40:
    print("Grade: D")
    print("PASSED")
    print("Remarks: Poor")
elif percentage>=33:
    print("GRADE: E")
    print("PASSED")
    print("Remarks: VERY POOR/NEED IMPROVEMENT")
else:
    print("GRADE: F")
    print("FAILED")
    print("REMARKS: VERY VERY POOR/NEED HIGH LEVEL IMPROVEMENT")
print("\n\n"+Fore.RED+"DATED:-\t\t\t\t\t\tPRINCIPAL SIGNATURE:-")
# Out:
# Enter Serial Number:123456
# Enter Roll Number:160180107003
# Enter Student Name:Anant Kala
# Enter Student Father Name:Arun Kumar Kala
# Enter Student Mother Name:Deepa Kala
# Enter Student Date of Birth:11011999
# Enter Student Date of Birth in Words:Eleven January Nineteen Hundred Ninety Nine
# Enter Student Class:12
# Enter Student School Name:Saraswati Vidya Mandir Pauri Garhwal
# Enter Student School Code:358
# Enter Student Certificate Number:789456
# Enter Student Exam Type:Full Time
# Enter English marks:78
# Enter Physics marks:87
# Enter Chemistry marks:89
# Enter Maths marks:95
# Enter Hindi marks:92
# 441
# 88.2
#
#
#
# Sr. No
# 123456
# 				BOARD OF SCHOOL EDUCATION UTTRAKHAND
# 				  CERTIFIACTE MARKS STATEMENT
# 				     INTERMEDIATE EXAMINATION
#
#
#
# STUDENT NAME: Anant Kala
#
# STUDENT ROLL NO: 160180107003
#
# STUDENT FATHERS NAME: Arun Kumar Kala
#
# STUDENT MOTHERS NAME: Deepa Kala
#
# STUDENT CLASS: 12
#
# DATE OF BIRTH: 11011999
#
# ...
